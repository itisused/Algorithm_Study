# %% [markdown]
# ## 모든 문제: 월간 코드 챌린지 시즌2
# - 진행 현황
#
# |날짜|완료|진행중|일시중단|대기|
# |:-:|--|--|--|--|
# |2022.03.11|1|-|-|2, 3, 4, 5, 6, 7, 8|

# %% [markdown]
# ### 1) [음양 더하기](https://programmers.co.kr/learn/courses/30/lessons/76501) (Lv. 1)
#
# |날짜|비고||
# |--|--|--|
# |2022-03-11|1) 개념|?|
# ||2) 실패 방식|-|
# ||3) 풀이 방식|-|
# ||4) 그 외|-|

# %%
def solution(absolutes, signs):
    s = 0
    for num, pm in zip(absolutes, signs):
        if pm:
            s = s + num
        else:
            s = s - num
    answer = s
    return answer
