# %% [markdown]
# ## 코딩테스트 고득점 Kit: [정렬](https://programmers.co.kr/learn/courses/30/parts/12198)
# - 진행 현황
#
# |날짜|완료|진행중|일시중단|대기|
# |:-:|--|--|--|--|
# |2022.??.??|1|-|-|2, 3|

# %% [markdown]
# ### 1) [K번째수](https://programmers.co.kr/learn/courses/30/lessons/42748) (Lv. 1)
#
# |날짜|비고||
# |--|--|--|
# |2022.??.??|||

# %%
def solution(array, commands):
    answer = []
    for a in range(len(commands)):
        # start = commands[a][0]
        # end = commands[a][1]
        # loc = commands[a][2]
        
        test_array = array[commands[a][0]-1:commands[a][1]]
        test_array.sort()
        answer.append(test_array[commands[a][2]-1])
    return answer
